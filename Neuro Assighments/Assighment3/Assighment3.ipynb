# %%
from IPython.core.display import HTML

# Apply styles globally within the notebook

HTML('''
<style>
  h2 {
    font-size: var(--j3p-content-font-size4);
    background-color:#00FF00  ;
    color: white;
    display: flex;
    align-items: center;
    justify-content: center;
    padding: 10px 41px;
    top: 10px;
    position: relative;
    border-radius: 10px 50px 10px 50px;
}

 img {       /* flex-grow: 1; */
            /* flex-shrink: 1; */
            border-radius: 100px 70px 150px 70px; 
            border: 10px solid #eee;
            display: flex;
            align-items: center;
            justify-content: center;
            transition: box-shadow 0.3s ease; /* Add a transition for a smooth effect */
        }

       img:active {
          box-shadow: 0 10px 20px rgba(255, 255, 0, 0.5), 0 6px 6px rgba(215, 215, 0, 0.5);
        }
</style>
''')
# Out:
# <style>
#   h2 {
#     font-size: var(--j3p-content-font-size4);
#     background-color:#00FF00  ;
#     color: white;
#     display: flex;
#     align-items: center;
#     justify-content: center;
#     padding: 10px 41px;
#     top: 10px;
#     position: relative;
#     border-radius: 10px 50px 10px 50px;
# }
#
#  img {       /* flex-grow: 1; */
#             /* flex-shrink: 1; */
#             border-radius: 100px 70px 150px 70px;
#             border: 10px solid #eee;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             transition: box-shadow 0.3s ease; /* Add a transition for a smooth effect */
#         }
#
#        img:active {
#           box-shadow: 0 10px 20px rgba(255, 255, 0, 0.5), 0 6px 6px rgba(215, 215, 0, 0.5);
#         }
# </style>

# %% [markdown]
# <img src="Neuro.jpg" alt="My Image">

# %% [markdown]
# ## Created By  : Eng/AbdalRhman Gameel Ahmed Hebishy
#
#
# <div style="border: 5px solid yellow; padding: 10px; background-color: #F5F5DC; color: blue; border-radius: 30px 45px 30px 45px;">
#
# <p>&bull;  AbdalRhman Hebishy , DataScientist||Machine learning||Deeplearning Engineer .</p>
#
# <p>&bull; <a href="https://www.kaggle.com/abdalrhamnhebishy" target="_blank">Kaggle profile</a>.</p>
#
# <p>&bull; <a href="https://github.com/AbdalRahmna" target="_blank">Github profile</a>.</p>
#
# <p>&bull; <a href="https://www.linkedin.com/in/abdalrahman-hebishy-06465b254/"_blank">linkedin profile</a>.</p>
#
#
# </div>

# %% [markdown]
# ## Question 1: What is the definition of probability?
#
# <div style="border: 5px solid yellow; padding: 10px; background-color: #F5F5DC; color: blue; border-radius: 30px 45px 30px 45px;">
#
# <p>b) A measure of the likelihood of an event.</p>
#
#
#
#
# </div>

# %% [markdown]
# ## Question 2: What is a sample space?
#
# <div style="border: 5px solid yellow; padding: 10px; background-color: #F5F5DC; color: blue; border-radius: 30px 45px 30px 45px;">
#
# <p>b) The set of all possible outcomes</p>
#
#
#
# </div>

# %% [markdown]
# ## Question 3: What is the sample space for rolling two dice?
#
# <div style="border: 5px solid yellow; padding: 10px; background-color: #F5F5DC; color: blue; border-radius: 30px 45px 30px 45px;">
#
# <p>b) {(1,1), (1,2), (2,1), (2,2), ..., (6,6)}</p>
#
#
#
# </div>

# %% [markdown]
# ## Question 4: What is the probability of drawing a yellow marble from a bag containing 3 red, 2 yellow, and 1 blue marble?
#
# <div style="border: 5px solid yellow; padding: 10px; background-color: #F5F5DC; color: blue; border-radius: 30px 45px 30px 45px;">
#
# <p>b) 2/6</p>
#
#
#
# </div>

# %% [markdown]
# ## Question 5:If you flip a fair coin, what is the probability of getting tails??
#
# <div style="border: 5px solid yellow; padding: 10px; background-color: #F5F5DC; color: blue; border-radius: 30px 45px 30px 45px;">
#
# <p>c) 0.5</p>
#
#
#
# </div>

# %% [markdown]
# ## Question 6:If two events A and B are independent, what is the probability of both A and B occurring?
#
# <div style="border: 5px solid yellow; padding: 10px; background-color: #F5F5DC; color: blue; border-radius: 30px 45px 30px 45px;">
#
# <p>b) P(A) × P(B)</p>
#
#
#
# </div>

# %% [markdown]
# <div style="border: 5px solid yellow; padding: 10px; background-color: #F5F5DC; color: blue; border-radius: 30px 45px 30px 45px;">
#
# ## Question 7:What is the probability of rolling a 4 on a six-sided die and drawing a red card from a deck of cards?
#
# <p>b) 1/6 × 26/52</p>
#
# ## Question 8:What does P(A∣B) represent?
#
# <p>a) The probability of A given B</p>
#
# ## Question 9:If P(A) = 0.4 and P(A∣B) = 0.5, what is P(A∩B) given P(B) = 0.8?
#
# <p>c) 0.32</p>
#
# ## Question 10: What is the probability of drawing a queen or a heart from a standard deck of 52 cards?
#
# <p>c) 17/52</p>
#
# ## Question 11: If the probability of event A is 0.6 and event B is 0.7, what is the probability of either A or B occurring if A and B are mutually exclusive?
#
# <p>d) 0.7</p>
#
# ## Question 12 :  What does Bayes' Theorem help us calculate?
#
# <p>b) The conditional probability of an event based on prior knowledge and new evidence</p>
#
# </div>

# %% [markdown]
# <div style="border: 5px solid yellow; padding: 10px; background-color: #F5F5DC; color: blue; border-radius: 30px 45px 30px 45px;">
#
# ##  Question 13:In Bayes' Theorem, what does P(A∣B) represent?
#
# <p> c) The probability of event A given event B</p>
#
# ## Question 14: What does P(B∣A) represent in Bayes' Theorem?
#
# <p> c) The probability of observing event B given that event A has occurred</p>
#
# ## Question 15:To derive Bayes' Theorem, which basic probability concept is used?
#
# <p> d) Law of Total Probability</p>
#
# ## Question 16: If P(A) = 0.4, P(B∣A) = 0.5, and P(B) = 0.8, what is P(A∣B)?
#
# <p>a) 0.25</p>
#
# ## Question 17: Which of the following is NOT a typical application of Bayes' Theorem?
#
# <p> c) Linear regression</p>
#
# ## Question 18: Which of the following is NOT a component of Bayes' Theorem?
#
# <p> d) P(A)</p>
#
# ## Question 19: What is a random variable?
#
# <p> a) A function that assigns a real number to each possible outcome of a random experiment</p>
#
# </div>

# %% [markdown]
# <div style="border: 5px solid yellow; padding: 10px; background-color: #F5F5DC; color: blue; border-radius: 30px 45px 30px 45px;">
#
# ## Which of the following is an example of a random variable?
#
# <p> a) The height of a person</p>
#
# ## Which of the following is a characteristic of a discrete random variable?
#
# <p>c) Takes on a countable number of distinct values</p>
#
# ## What is associated with continuous random variables?
#
# <p>b) Probability density function (PDF)</p>
#
# ## Which of the following is an example of a discrete random variable?
#
# <p> c) The number of defective items in a batch</p>
#
# ## Which of the following is an example of a continuous random variable?
#
# <p> c) The time it takes to complete a test</p>
#
# ## What distinguishes discrete random variables from continuous random variables?
# <p> c) Discrete random variables have a PMF, while continuous random variables have a PDF</p>
#
# ## What notation is commonly used for both discrete and continuous random variables?
# <p> c) Uppercase letters</p>
#
#
# </div>

# %% [markdown]
# <div style="border: 5px solid yellow; padding: 10px; background-color: #F5F5DC; color: blue; border-radius: 30px 45px 30px 45px;">
#
# ## What does a discrete probability distribution represent?
#
# <p>b) The probability of different outcomes in a discrete set</p>
#
# ## Which of the following is a common example of a discrete probability distribution?
#
# <p>b) Poisson distribution</p>
#
# ## What is a Bernoulli distribution used to model?
#
# <p>b) Outcomes with two possible results</p>
#
# ## In a Bernoulli trial, if the probability of success is denoted by \( p \), what is the probability of failure?
#
# <p>c)  1 - p</p>
#
# ## Which scenario is best modeled by a binomial distribution?
#
# <p>a) The number of defective items in a batch</p>
#
# ## In a binomial distribution, what does \( n \) represent?
#
# <p>b) The number of trials</p>
#
# ## What distinguishes a hypergeometric distribution from a binomial distribution?
#
# <p>a) The hypergeometric distribution does not assume replacement in trials</p>
#
# </div>

# %% [markdown]
# <div style="border: 5px solid yellow; padding: 10px; background-color: #F5F5DC; color: blue; border-radius: 30px 45px 30px 45px;">
#
# ## In a hypergeometric distribution, what does  N  represent?
#
# <p>b) The size of the population</p>
#
# ## What does a geometric distribution measure?
#
# <p>a) The number of failures before a specified number of successes</p>
#
# ## In a geometric distribution, if  p  is the probability of success, what does k  represent?
#
# <p>b) The number of failures before the first success</p>
#
# ## Which type of event is best modeled by a Poisson distribution?
#
# <p>a) Events with fixed intervals of time or space</p>
#
# ## In a Poisson distribution, what does lambda  represent?
#
# <p>b) The average number of occurrences in a fixed interval</p>
#
# ## What is a multinomial distribution model?
#
# <p>c) The probability of multiple outcomes with many possible results</p>
#
# ## In a multinomial distribution, what does  n  represent?
#
# <p>a) The number of trials</p>
#
#
#
# </div>

# %% [markdown]
# <div style="border: 5px solid yellow; padding: 10px; background-color: #F5F5DC; color: blue; border-radius: 30px 45px 30px 45px;">
#
#
# ## What distinguishes continuous probability distributions from discrete ones?
#
# <p>b) Continuous distributions describe outcomes over an interval, not exact values</p>
#
# ## Which function is used to define continuous probability distributions?
#
# <p>b) Probability Density Function (PDF)</p>
#
# ## What is a continuous uniform distribution model?
#
# <p>a) Random variables with equal probabilities within a range</p>
#
# ## Which of the following is a key property of the normal distribution?
#
# <p>a) It has two parameters: mean and standard deviation</p>
#
# ## In a standard normal distribution, what are the mean mu  and standard deviation sigma ?
#
# <p> a) μ=0 and σ=1 </p>
#
# ## What is the log-normal distribution used to model?
#
# <p> a) Random variables whose logarithms follow a normal distribution </p>
#
# ## What does the PDF of a log-normal distribution depend on?
#
# <p> a) Mean and variance of the normal distribution of ln⁡(X)\ln(X)ln(X) </p>
# </div>

# %% [markdown]
# <div style="border: 5px solid yellow; padding: 10px; background-color: #F5F5DC; color: blue; border-radius: 30px 45px 30px 45px;">
#
# ## What happens to the Student’s t distribution as the sample size increases?
#
# <p> a) It approaches the normal distribution</p>
#
# ## In the chi-square distribution, what does the degrees of freedom  p  represent?
#
# <p> d) The number of observed values minus the number of expected values </p>
#
# ## In the exponential distribution, what does lambda  represent?
#
# <p> a) The rate parameter, or the inverse of the average time between events</p>
#
# ## For a continuous random variable  X  how is the expected value calculated?
#
# <p>b) Integrating the product of the variable and its PDF over the entire range</p>
#
# ## For a continuous random variable  X  how is the variance calculated?
#
# <p> a) By integrating the squared differences between the variable and its expected value, weighted by the PDF</p>
#
# ## What is the primary difference between expectation (expected value) and variance?
#
# <p> a) Expectation measures the average value, while variance measures the spread around that value</p>
#
#
# </div>

# %% [markdown]
# <img src="https://t4.ftcdn.net/jpg/04/00/26/99/360_F_400269908_gDF8JR2ctyHWiL1kww6WEWBerRzD5MBb.jpg" alt="My Image">
